# %%
import pandas as pd
import numpy as np
from tqdm import tqdm_notebook as tqdm
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../input/commonlitreadabilityprize/train.csv")

# %%
df["wikipedia"] = ["wikipedia" in x for x in df["url_legal"].fillna("").values]

# %%
df[df["url_legal"].notnull()].head(40)
# Out:
#             id                                          url_legal  \
# 249  07de53e3c  https://simple.wikipedia.org/wiki/Battle_of_Br...
# 250  a26e55bea  https://simple.wikipedia.org/wiki/Battle_of_Sa...
# 251  5127fb10f  https://simple.wikipedia.org/wiki/Battle_of_Wa...
# 253  0d3a8f33b             https://en.wikipedia.org/wiki/Big_data
# 254  7073d1ef3            https://en.wikipedia.org/wiki/Biodiesel
# 255  e83e2cc69         https://en.wikipedia.org/wiki/Biodiversity
# 256  e4d810c98        https://en.wikipedia.org/wiki/Biotechnology
# 257  c46e26fb6  https://kids.frontiersin.org/article/10.3389/f...
# 258  688e3c808              https://en.wikipedia.org/wiki/Bitcoin
# 259  6ee4f1df3           https://en.wikipedia.org/wiki/Black_hole
# 260  bba96ae90             https://en.wikipedia.org/wiki/Blockade
# 261  6849b506d            https://simple.wikipedia.org/wiki/Blood
# 262  9ebae047b        https://simple.wikipedia.org/wiki/Bluetooth
# ...

# %%
df.groupby("wikipedia")["target"].describe()
# Out:
#             count      mean       std       min       25%       50%       75%  \
# wikipedia
# False      2462.0 -0.921464  1.047653 -3.676268 -1.671030 -0.861470 -0.135632
# True        372.0 -1.209851  0.896894 -3.549190 -1.847025 -1.238783 -0.574985
#
#                 max
# wikipedia
# False      1.711390
# True       1.268987

# %%
w_df = df[df["wikipedia"]] 

for i in range(100):
    print("==========================")
    print(w_df.iloc[i]["target"])
    print(w_df.iloc[i]["url_legal"])
    print(w_df.iloc[i]["id"])
    print(w_df.iloc[i]["excerpt"])
# Out:
# ...
# -0.156618699
# https://simple.wikipedia.org/wiki/Battle_of_Britain
# 07de53e3c
# The Battle of Britain was an attack by the German Air Force (Luftwaffe) on Great Britain during the summer and autumn of 1940.
# The first objective of the campaign was to gain control of the air space above Britain from the Royal Air Force (RAF), especially Fighter Command.
# The name comes from a famous speech delivered by Prime Minister Winston Churchill in the House of Commons: "The Battle of France is over. I expect the Battle of Britain is about to begin..."
# The Battle of Britain was the first major campaign to be fought entirely by air forces, and was also the largest and longest aerial bombing campaign to that date.
# ...
